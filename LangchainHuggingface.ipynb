# %%
import os
from dotenv import load_dotenv
from langchain_huggingface import HuggingFaceEndpoint
from langchain.llms import HuggingFaceHub

load_dotenv()

from huggingface_hub import InferenceClient

client = InferenceClient(token=os.getenv("HF_TOKEN"))  # Token'ı burada kullanın

try:
    response = client.text_generation(
        model="google/flan-t5-base",  # Daha küçük modelle deneyin
        prompt="What is machine learning?",
        max_new_tokens=50
    )
    print(response)
except Exception as e:
    print(f"Hata oluştu: {str(e)}")
# Out:
# Hata oluştu: 401 Client Error: Unauthorized for url: https://huggingface.co/api/models/google/flan-t5-base?expand=inferenceProviderMapping (Request ID: Root=1-6889df0a-794e75721f24607803766eef;69c770ea-f591-405f-9f7d-e5ce0856879f)
#
# Invalid credentials in Authorization header

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import InferenceClient

load_dotenv(override=True)
client = InferenceClient(token=os.getenv("HF_TOKEN"))

# Bu kesinlikle çalışır
try:
    response = client.text_generation(
        model="openai-community/gpt2",  # %100 ücretsiz
        prompt="What is machine learning?",
        max_new_tokens=50
    )
    print(response)
except Exception as e:
    print(f"Hata: {e}")
# Out:
# Hata:

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import InferenceClient

# Adım 1: Environment debug
print("🔍 ENVIRONMENT DEBUG:")
print("="*40)

load_dotenv(override=True)

# Token kontrol et
hf_token = os.getenv("HF_TOKEN")
print(f"HF_TOKEN loaded: {hf_token is not None}")
print(f"Token length: {len(hf_token) if hf_token else 0}")
print(f"Token starts with 'hf_': {hf_token.startswith('hf_') if hf_token else False}")

# .env dosyası kontrol
env_file_exists = os.path.exists('.env')
print(f".env file exists: {env_file_exists}")

if env_file_exists:
    with open('.env', 'r') as f:
        content = f.read()
    print(f".env content (first 50 chars): {content[:50]}...")
    print(f"Contains HF_TOKEN: {'HF_TOKEN' in content}")

print("\n" + "="*40)

# Adım 2: Manual token test
print("🧪 MANUAL TOKEN TEST:")
print("="*40)

# Token'ı manuel olarak gir (geçici test için)
# MANUAL_TOKEN = "hf_xxxxxxxxxxxxxxxxx"  # Buraya token'ınızı yazın
MANUAL_TOKEN = None  # Şimdilik None, yukarıdaki satırı açın

if MANUAL_TOKEN:
    print("Testing with manual token...")
    client_manual = InferenceClient(token=MANUAL_TOKEN)
    try:
        response = client_manual.text_generation(
            model="openai-community/gpt2",
            prompt="Hello",
            max_new_tokens=10
        )
        print(f"✅ Manual token works: {response}")
    except Exception as e:
        print(f"❌ Manual token error: {e}")

# Adım 3: Token olmadan test
print("\n🔓 TOKEN OLMADAN TEST:")
print("="*40)

try:
    client_no_token = InferenceClient()  # Token olmadan
    response = client_no_token.text_generation(
        model="openai-community/gpt2",
        prompt="Hello",
        max_new_tokens=10
    )
    print(f"✅ Works without token: {response}")
except Exception as e:
    print(f"❌ Without token error: {e}")

# Adım 4: Alternatif yöntem - transformers pipeline
print("\n🔄 ALTERNATIF: TRANSFORMERS PİPELİNE:")
print("="*40)

try:
    from transformers import pipeline
    
    print("Loading pipeline...")
    generator = pipeline("text-generation", model="openai-community/gpt2")
    
    result = generator(
        "What is machine learning?", 
        max_length=50, 
        num_return_sequences=1,
        temperature=0.7
    )
    
    print(f"✅ Transformers pipeline works:")
    print(result[0]['generated_text'])
    
except Exception as e:
    print(f"❌ Transformers error: {e}")
    print("Run: pip install transformers")

# Adım 5: Çözüm önerileri
print("\n" + "="*40)
print("🔧 ÇÖZÜM ÖNERİLERİ:")
print("="*40)

solutions = """
1. .env dosyasını kontrol edin:
   Dosya içeriği: HF_TOKEN=hf_xxxxxxxxxxxxxxxxx
   
2. Token formatını kontrol edin:
   - 'hf_' ile başlamalı
   - 37 karakter uzunluğunda olmalı
   
3. Yeni token oluşturun:
   - https://huggingface.co/settings/tokens
   - "New token" -> "Read" yetkisi yeterli
   
4. Manuel test yapın:
   - Yukarıdaki MANUAL_TOKEN kısmını açın
   - Token'ınızı yazın ve test edin
   
5. Transformers kullanın:
   - Yukarıdaki pipeline yöntemi token gerektirmez
   - Model local olarak indirilir
"""

print(solutions)

# Adım 6: Hızlı çözüm kodu
print("\n" + "="*40)
print("⚡ HIZLI ÇÖZÜM KODU:")
print("="*40)

quick_solution = '''
# Yöntem 1: Direct token
from huggingface_hub import InferenceClient
client = InferenceClient(token="hf_your_token_here")

# Yöntem 2: Environment variable
import os
os.environ["HF_TOKEN"] = "hf_your_token_here"
client = InferenceClient(token=os.environ["HF_TOKEN"])

# Yöntem 3: No token needed (transformers)
from transformers import pipeline
generator = pipeline("text-generation", model="openai-community/gpt2")
result = generator("What is machine learning?", max_length=50)
print(result[0]['generated_text'])
'''

print(quick_solution)
# Out:
# 🔍 ENVIRONMENT DEBUG:
# ...
# HF_TOKEN loaded: True
# Token length: 37
# Token starts with 'hf_': True
# .env file exists: False
#
# ...
# 🧪 MANUAL TOKEN TEST:
# ...
#
# 🔓 TOKEN OLMADAN TEST:
# ...
# ❌ Without token error:
#
# 🔄 ALTERNATIF: TRANSFORMERS PİPELİNE:
# ...
# Loading pipeline...
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# WARNING:tensorflow:From c:\dev\Python\.venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# ...

# %%
import os
from huggingface_hub import InferenceClient

# .env dosyanızdaki tokenı kontrol edin
hf_token = os.getenv("HF_TOKEN") or os.getenv("HUGGINGFACEHUB_API_TOKEN")

# Token formatını doğrulayın
print(f"Token uzunluğu: {len(hf_token)} karakter")  # Genellikle 30-40 karakter olmalı
print(f"Token örneği: {hf_token[:5]}...{hf_token[-5:]}")
# Out:
# Token uzunluğu: 37 karakter
# Token örneği: hf_Rb...DrOsf

# %%
import requests
import os
from dotenv import load_dotenv

# .env dosyasını yükle
load_dotenv()

# Token'ı al ve kontrol et
token = os.getenv("HF_TOKEN")
if not token:
    print("Hata: HF_TOKEN çevresel değişkeni bulunamadı. Lütfen .env dosyasını kontrol edin.")
    exit(1)

print("Kullanılan Token:", token[:10] + "..." + token[-5:])  # Token'ın bir kısmını göster
headers = {"Authorization": f"Bearer {token}"}

# 1. Adım: Token geçerlilik testi
response = requests.get("https://huggingface.co/api/whoami", headers=headers)
print(f"Token test sonucu (HTTP {response.status_code}):", response.text)

# 2. Adım: Model erişim testi
if response.status_code == 200:
    model_test = requests.post(
        "https://api-inference.huggingface.co/models/google/flan-t5-small",
        headers=headers,
        json={"inputs": "What is ML?"}
    )
    print(f"Model test sonucu (HTTP {model_test.status_code}):", model_test.text)
else:
    print("Token geçersiz, lütfen yeni token oluşturun: https://huggingface.co/settings/tokens")
# Out:
# Kullanılan Token: hf_RbgYGHl...DrOsf
# Token test sonucu (HTTP 401): {"error":"Invalid credentials in Authorization header"}
# Token geçersiz, lütfen yeni token oluşturun: https://huggingface.co/settings/tokens

# %%
import os
from dotenv import load_dotenv

# .env dosyasını yükle
load_dotenv(override=True)  # Mevcut çevresel değişkenleri ezmek için override=True

# Token'ı al ve kontrol et
token = os.getenv("HF_TOKEN")
if token:
    print("Yüklenen Token:", token[:10] + "..." + token[-5:])
else:
    print("Hata: HF_TOKEN çevresel değişkeni yüklenemedi.")
# Out:
# Yüklenen Token: hf_bXxMtjM...lqnxB

# %%
import requests
import os
from dotenv import load_dotenv

# .env dosyasını yükle
load_dotenv(override=True)

# Token'ı al ve kontrol et
token = os.getenv("HF_TOKEN")
if not token:
    print("Hata: HF_TOKEN çevresel değişkeni yüklenemedi.")
    exit(1)

print("Yüklenen Token:", token[:10] + "..." + token[-5:])
headers = {"Authorization": f"Bearer {token}"}

# Token geçerlilik testi (/api/whoami)
try:
    response = requests.get("https://huggingface.co/api/whoami", headers=headers)
    print(f"Whoami testi (HTTP {response.status_code}):", response.text)
except requests.exceptions.RequestException as e:
    print("Bağlantı hatası (whoami):", str(e))

# Model listesi testi (/api/models)
try:
    models_response = requests.get("https://huggingface.co/api/models", headers=headers)
    print(f"Model listesi testi (HTTP {models_response.status_code}):", models_response.text[:100] + "...")  # Uzun yanıtı kısalt
except requests.exceptions.RequestException as e:
    print("Bağlantı hatası (models):", str(e))

# Model erişim testi
try:
    model_test = requests.post(
        "https://api-inference.huggingface.co/models/google/flan-t5-small",
        headers=headers,
        json={"inputs": "What is ML?"}
    )
    print(f"Model test sonucu (HTTP {model_test.status_code}):", model_test.text)
except requests.exceptions.RequestException as e:
    print("Model testi bağlantı hatası:", str(e))
# Out:
# Yüklenen Token: hf_GbraQli...EPkoR
# Whoami testi (HTTP 401): {"error":"Invalid credentials in Authorization header"}
# Model listesi testi (HTTP 200): [{"_id":"687c61b066d1fc7f73788fc2","id":"zai-org/GLM-4.5","likes":676,"trendingScore":676,"private":...
# Model test sonucu (HTTP 404): Not Found

# %%
import requests
import os
from dotenv import load_dotenv

# .env dosyasını yükle
load_dotenv(override=True)

# Token'ı al ve kontrol et
token = os.getenv("HF_TOKEN")
if not token:
    print("Hata: HF_TOKEN çevresel değişkeni yüklenemedi.")
    exit(1)

print("Yüklenen Token:", token[:10] + "..." + token[-5:])
headers = {"Authorization": f"Bearer {token}"}

# facebook/bart-large testi
try:
    bart_test = requests.post(
        "https://api-inference.huggingface.co/models/facebook/bart-large",
        headers=headers,
        json={
            "inputs": "Question: What is Machine Learning? Answer:",
            "parameters": {"max_length": 100, "temperature": 0.7}
        }
    )
    print(f"BART testi (HTTP {bart_test.status_code}):", bart_test.text)
except requests.exceptions.RequestException as e:
    print("BART testi bağlantı hatası:", str(e))
# Out:
# Yüklenen Token: hf_GbraQli...EPkoR
# ...

# %%
import os
from huggingface_hub import InferenceClient
from dotenv import load_dotenv

# .env dosyasını yükle
load_dotenv(override=True)

# Token'ı al ve kontrol et
token = os.getenv("HF_TOKEN")
if not token:
    print("Hata: HF_TOKEN çevresel değişkeni yüklenemedi.")
    exit(1)

print("Yüklenen Token:", token[:10] + "..." + token[-5:])

# InferenceClient oluştur
client = InferenceClient(api_key=token)

# facebook/bart-large testi
try:
    result = client.text_generation(
        model="facebook/bart-large",
        prompt="Question: What is Machine Learning? Answer:",
        generate_kwargs={"max_new_tokens": 100, "temperature": 0.7}
    )
    print("BART text generation sonucu:", result)
except Exception as e:
    print("BART text generation hatası:", str(e))
# Out:
# Yüklenen Token: hf_GbraQli...EPkoR
# BART text generation hatası: InferenceClient.text_generation() got an unexpected keyword argument 'generate_kwargs'

# %%
import langchain
import huggingface_hub
import langchain_community

print("langchain:", langchain.__version__)
print("huggingface_hub:", huggingface_hub.__version__)
print("langchain_community:", langchain_community.__version__)
# Out:
# langchain: 0.3.26
# huggingface_hub: 0.33.1
# langchain_community: 0.3.25
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\dev\Python\.venv\Lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\dev\Python\.venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/models/google/flan-t5-xxl?expand=inferenceProviderMapping
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[72], line 20
# ...

# %%
from huggingface_hub import InferenceClient

client = InferenceClient()
response = client.text_generation(
    model="google/flan-t5-xxl",  # Daha güncel bir sürüm
    prompt="What is machine learning?",
    temperature=0.7,
    max_new_tokens=150
)
print(response)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\dev\Python\.venv\Lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\dev\Python\.venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/models/google/flan-t5-xxl?expand=inferenceProviderMapping
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[71], line 4
#       1 from huggingface_hub import InferenceClient
#       3 client = InferenceClient()
# ...

# %%
llm = HuggingFaceHub(
    repo_id="google/flan-t5-large",
    task="text2text-generation",
    model_kwargs={
        "temperature": 0.7,
        "max_new_tokens": 150
    }
)

response = llm.invoke("What is machine learning?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 10
#       1 llm = HuggingFaceHub(
#       2     repo_id="google/flan-t5-large",
#       3     task="text2text-generation",
#    (...)      7     }
#       8 )
# ---> 10 response = llm.invoke("What is machine learning?")
#      11 print(response)
#
# File c:\dev\Python\.venv\Lib\site-packages\langchain_core\language_models\llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)    385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
#     392             callbacks=config.get("callbacks"),
#     393             tags=config.get("tags"),
# ...

# %%
response = llm.invoke("What is the machine learning?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 response = llm.invoke("What is the machine learning?")
#       2 print(response)
#
# File c:\dev\Python\.venv\Lib\site-packages\langchain_core\language_models\llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)    385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
#     392             callbacks=config.get("callbacks"),
#     393             tags=config.get("tags"),
#     394             metadata=config.get("metadata"),
#     395             run_name=config.get("run_name"),
#     396             run_id=config.pop("run_id", None),
# ...
